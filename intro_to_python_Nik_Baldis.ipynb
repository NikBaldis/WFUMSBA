# %% [markdown]
# # Project 1 - Introduction to Python
#
# ---
#
# - Your Name Here: Niklas Baldis
# - WFU Email Address: baldnj23@wfu.edu
# - Submission Date: 7/16/23

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Instructions
#
#
# 1. Download the `intro_to_python_yournamehere.ipynb` file from the course website.
#
# 2. Open the notebook on your local computer; Or upload and open it in Google Colab.
#
# 3. Replace the placeholder text above with your name, email address, and submission date.
#
# 4. This is a simple project made up of mini-tasks. Simply write the code to answer the question, and be sure to `print()` the result!
#
# 5. Please submit your notebook in **HTML** on Canvas. Share its Colab link as a comment if you like.

# %% [markdown]
# # MSBA Alumni Database
#
# Since the inception of the program, many MSBA graduates have successfully secured analytics roles across various sectors within the United States and other countries. In this project, let’s get to know them and their career by creating an MSBA Alumni Database using a List of Dictionaries!

# %% [markdown]
# Task 0.	Start by creating an empty list called alumni_list and a dictionary called alumni_dict. Print their types respectively.
#
# ```python
# alumni_list = []
# alumni_dict = {}
# ```

# %%
alumni_list = []
alumni_dict = {}

# %%
type(alumni_list)
# Out:
# list

# %%
type(alumni_dict)
# Out:
# dict

# %% [markdown]
# Task 1.	Leverage your **LinkedIn network** to explore profiles of MSBA Alumni. Use `input()` to prompt and enter the following information about your 1st Alumni instance:
# - Name
# - MSBA Cohort
# - Current Organization
# - Current Position
#
# The info should go into a dictionary which is appended to your list later. For example:
#
# ```python
# # Add MSBA gradutes to the Alumni database
# alumni_dict["Name"] = input("Enter the Alumni's name: ")
# alumni_dict["Cohort"] = int(input("Enter the cohort: "))
# alumni_dict["Org"] = input("Enter the organization: ")
# alumni_dict["Position"] = input("Enter the position: ")
#
# ```

# %%
alumni_dict["Name"] = input("Enter the Alumni's name: ")
alumni_dict["Cohort"] = int(input("Enter the cohort: "))
alumni_dict["Org"] = input("Enter the organization: ")
alumni_dict["Position"] = input("Enter the position: ")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-149-b8b988795c40> in <cell line: 1>()
# ----> 1 alumni_dict["Name"] = input("Enter the Alumni's name: ")
#       2 alumni_dict["Cohort"] = int(input("Enter the cohort: "))
#       3 alumni_dict["Org"] = input("Enter the organization: ")
#       4 alumni_dict["Position"] = input("Enter the position: ")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %% [markdown]
# Task 2. Prompt yourself several times to record the following information for at least 4 people that you did research (may need to copy your code several times or use a loop).
#
# Examples:
# - {"Name": "Jerry", "Cohort": 2019, "Org": "Capital One", "Position": "Senior Business Analyst"}
# - {"Name": "Elaine", "Cohort": 2022, "Org": "Carnival Cruise Line", "Position": "Business Intelligence Analyst"}
# - etc..

# %%
alumni_dict["Name"] = input("Enter the Alumni's name: ")
alumni_dict["Cohort"] = int(input("Enter the cohort: "))
alumni_dict["Org"] = input("Enter the organization: ")
alumni_dict["Position"] = input("Enter the position: ")

# %%
alumni_dict["Name"] = input("Enter the Alumni's name: ")
alumni_dict["Cohort"] = int(input("Enter the cohort: "))
alumni_dict["Org"] = input("Enter the organization: ")
alumni_dict["Position"] = input("Enter the position: ")

# %%
alumni_dict["Name"] = input("Enter the Alumni's name: ")
alumni_dict["Cohort"] = int(input("Enter the cohort: "))
alumni_dict["Org"] = input("Enter the organization: ")
alumni_dict["Position"] = input("Enter the position: ")

# %%
alumni_dict["Name"] = input("Enter the Alumni's name: ")
alumni_dict["Cohort"] = int(input("Enter the cohort: "))
alumni_dict["Org"] = input("Enter the organization: ")
alumni_dict["Position"] = input("Enter the position: ")

# %% [markdown]
# Task 3.	Append each alumni dictionary to the alumni list. Then, make sure you:
# - Print out your list
# - Report the total number of MSBA Alumni in the list
#
# (Hint: Your list should look like the following.)
#
# ```python
# alumni_list = [
#     {
#         "Name": "Jerry",
#         "Cohort": 2019,
#         "Org": "Capital One",
#         "Position": "Senior Business Analyst"
#     },
#     {
#         "Name": "Elaine",
#         "Cohort": 2022,
#         "Org": "Carnival Cruise Line",
#         "Position": "Business Intelligence Analyst"
#     },
#     {
#         "Name": "George",
#         "Cohort": 2018,
#         "Org": "Wells Fargo",
#         "Position": "Senior Lead Analytics Consultant"
#     }
# ]
# ```

# %%
alumni_list = [
    {
        "Name": "Alex Chambers",
        "Cohort": "2021",
        "Org": "Delta Airlines",
        "Position": "Data Analyst"
    },
    {
        "Name": "Sarah Hayakawa",
        "Cohort": "2018",
        "Org": "Merkle, Inc.",
        "Position": "Digital Media Analytics"
    },
    {
        "Name": "Cal Brazier",
        "Cohort": "2021",
        "Org": "ZS Associates",
        "Position": "Strategy Inights & Planning Associate"
    },
    {
        "Name": "Linda Luo",
        "Cohort": "2022",
        "Org": "Wellnecity, LLC",
        "Position": "Business Analyst"
    },
    {
        "Name": "Jamey McDowell",
        "Cohort": "2018",
        "Org": "Meta",
        "Position": "Data Scientist"
    },
]

# %%
alumni_list

# %%
len(alumni_list)

# %% [markdown]
# Task 4. Append Sean to the alumni_list and print the updated list.
#
# ```python
# # Adding a new MSBA graduate
# new_alumni_dict = {
#     "Name": "Sean",
#     "Cohort": 2018,
#     "Org": "BHG Financial",
#     "Position": "Analytics Manager"
# }
# ```

# %%
alumni_list.append({
    "Name": "Sean",
    "Cohort": 2018,
    "Org": "BHG Financial",
    "Position": "Analytics Manager"
})

# %%
alumni_list

# %% [markdown]
# Task 5. Identify one individual from the MSBA Alumni database that you find particularly intriguing. Retrieve respective details and display them in this specific format: `"Sean is currently an Analytics Manager at BHG Financial."` Please make sure to use variables and `format()` in this task. The output should not be hard-coded.

# %%
alumni_list[-2]

# %%
name = "Jamey McDowell"
position = "Data Scientist"
org = "Meta"

print(f"{name} is currently a {position} at {org}.")

# %% [markdown]
# Task 6. Given the database you've created, please answer the following questions by printing out the respective results:
# - What's the position held by the 2nd MSBA Alumni?
# - Did the 1st Alumni graduate before the 4th Alumni (True or False)?
# - The 3rd Alumni recently started a new position at `Company X`. Can you update the relevant field in the database with this information, using a `list` of his/her current and previous organizations?

# %%
alumni_list[1]["Position"]

# %%
if alumni_list[3]['Cohort'] > alumni_list[0]['Cohort']:
  print("The 1st alumni graduated before the 4th.")
elif alumni_list[0]["Cohort"] > alumni_list[3]['Cohort']:
  print('The 1st alumni graduated after the 4th.')
else:
  print('They graduated the same year.')

# %%
alumni_list[2]

# %%
alumni_list[2]["Org"] = "Current: Company X, Previous: ZS Associates"

# %%
alumni_list[2]

# %%
# %%shell
# jupyter nbconvert --to html "/content/drive/MyDrive/Colab Notebooks/intro_to_python_Nik_Baldis.ipynb"

# %% [markdown]
# Task 7. Convert your notebook to HTML.
#
# You can do this by running this piece of code:
#
# ```python
# %%shell
# jupyter nbconvert --to html "/content/drive/MyDrive/your_notebook_path.ipynb"
#
# ```
# Or use the `Download as` feature in your local notebook:
#
# ![to_html.jpg](data:image/jpeg;base64,...)
